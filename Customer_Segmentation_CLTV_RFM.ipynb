# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-857db237-4e86-44d1-acd5-267d652b1bd2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-857db237-4e86-44d1-acd5-267d652b1bd2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('online_retail_II.csv')
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
df.shape
# Out:
# (1067371, 8)

# %%
df.isna().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      4382
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    243007
# Country             0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Invoice        0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# Price          0
# Customer ID    0
# Country        0
# dtype: int64

# %%
df.shape
# Out:
# (824364, 8)

# %%
df.loc[df.Invoice.str.contains('C',na=False)]
# Out:
#          Invoice StockCode                       Description  Quantity  \
# 178      C489449     22087          PAPER BUNTING WHITE LACE       -12
# 179      C489449    85206A      CREAM FELT EASTER EGG BASKET        -6
# 180      C489449     21895     POTTING SHED SOW 'N' GROW SET        -4
# 181      C489449     21896                POTTING SHED TWINE        -6
# 182      C489449     22083        PAPER CHAIN KIT RETRO SPOT       -12
# ...          ...       ...                               ...       ...
# 1065910  C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 1067002  C581499         M                            Manual        -1
# 1067176  C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 1067177  C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 1067178  C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                  InvoiceDate   Price  Customer ID         Country
# ...

# %%
df.loc[~df.Invoice.str.contains('C',na=False)]
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
df=df.loc[~df.Invoice.str.contains('C',na=False)]
df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
df['TotalPrice']= df.Quantity * df.Price
df.head()
# Out:
# <ipython-input-13-68b4b0cbc9f3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TotalPrice']= df.Quantity * df.Price
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country  TotalPrice
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom        83.4
# ...

# %%
df.Invoice.nunique()
# Out:
# 36975

# %%
df['Customer ID'].nunique()
# Out:
# 5881

# %%
#Cantidad de productos vendidos

df.groupby('Description').agg({'Quantity':'sum'}).sort_values(by='Quantity',ascending=False)
# Out:
#                                      Quantity
# Description
# WORLD WAR 2 GLIDERS ASSTD DESIGNS      109169
# WHITE HANGING HEART T-LIGHT HOLDER      93640
# PAPER CRAFT , LITTLE BIRDIE             80995
# ASSORTED COLOUR BIRD ORNAMENT           79913
# MEDIUM CERAMIC TOP STORAGE JAR          77916
# ...                                       ...
# F.FAIRY S/3 SML CANDLE, ROSE                1
# F.FAIRY S/3 SML CANDLE,LILY/VALLEY          1
# VINTAGE METAL CAKE STAND CREAM              1
# F.FAIRY,CANDLE IN GLASS,LILY/VALLEY         1
# RUSSIAN FOLKART STACKING TINS               1
#
# [5283 rows x 1 columns]

# %%
#Total por factura

df.groupby("Invoice").agg({"TotalPrice": "sum"}).sort_values(by='TotalPrice',ascending=False)
# Out:
#          TotalPrice
# Invoice
# 581483     168469.6
# 541431      77183.6
# 493819      44051.6
# 556444      38970.0
# 524181      33167.8
# ...             ...
# 568384          0.0
# 578841          0.0
# 497819          0.0
# 564651          0.0
# 497843          0.0
#
# [36975 rows x 1 columns]

# %%
df.describe().T
# Out:
#                 count          mean          std      min       25%       50%  \
# Quantity     805620.0     13.307665   144.306739      1.0      2.00      5.00
# Price        805620.0      3.206279    29.197901      0.0      1.25      1.95
# Customer ID  805620.0  15331.856250  1696.768395  12346.0  13982.00  15271.00
# TotalPrice   805620.0     22.024564   224.032150      0.0      4.95     11.85
#
#                   75%       max
# Quantity        12.00   80995.0
# Price            3.75   10953.5
# Customer ID  16805.00   18287.0
# TotalPrice      19.50  168469.6

# %%
#Le asignamos el precio de los cuartiles 1% y 99% a los outliears

o1=df['Price'].quantile(.01)
o3=df['Price'].quantile(.99)
inter_o=o3-o1
up_v=o3+inter_o*1.5
low_v=o1-inter_o*1.5
#low_v= low_v if low_v>=0 else 0


df.loc[df['Price']>up_v,'Price']=up_v
df.loc[df['Price']<low_v,'Price']=low_v

print(f'Percentil 1%: {o1}')
print(f'Percentil 99%: {o3}')
print(f'Rango Interpercentil: {inter_o}')
print(f'Limite Inferior: {low_v}')
print(f'Limite Superior: {up_v}')
df
# Out:
# Percentil 1%: 0.29
# Percentil 99%: 14.95
# Rango Interpercentil: 14.66
# Limite Inferior: -21.700000000000003
# Limite Superior: 36.94
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# ...

# %%
#Le asignamos las cantidades de los cuartiles 1% y 99% a los outliears

o1=df['Quantity'].quantile(.01)
o3=df['Quantity'].quantile(.99)
inter_o=o3-o1
up_v=o3+inter_o*1.5
low_v=o1-inter_o*1.5
#low_v= low_v if low_v>=0 else 0

df.loc[df['Quantity']>up_v,'Quantity']=up_v
df.loc[df['Quantity']<low_v,'Quantity']=low_v

print(f'Percentil 1%: {o1}')
print(f'Percentil 99%: {o3}')
print(f'Rango Interpercentil: {inter_o}')
print(f'Limite Inferior: {low_v}')
print(f'Limite Superior: {up_v}')
df
# Out:
# Percentil 1%: 1.0
# Percentil 99%: 128.0
# Rango Interpercentil: 127.0
# Limite Inferior: -189.5
# Limite Superior: 318.5
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS      12.0
# 1        489434    79323P                   PINK CHERRY LIGHTS      12.0
# 2        489434    79323W                  WHITE CHERRY LIGHTS      12.0
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE       48.0
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX      24.0
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL        6.0
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL        4.0
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE       4.0
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT        3.0
# ...

# %%
#Modificamos el formato de la columna de fecha

df["InvoiceDate"] = pd.to_datetime(df["InvoiceDate"])
df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS      12.0
# 1        489434    79323P                   PINK CHERRY LIGHTS      12.0
# 2        489434    79323W                  WHITE CHERRY LIGHTS      12.0
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE       48.0
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX      24.0
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL        6.0
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL        4.0
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE       4.0
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT        3.0
# 1067370  581587      POST                              POSTAGE       1.0
#
#                 InvoiceDate  Price  Customer ID         Country  TotalPrice
# ...

# %%
print("Farthest date:", df["InvoiceDate"].min())
print("Nearest date:", df["InvoiceDate"].max())
# Out:
# Farthest date: 2009-12-01 07:45:00
# Nearest date: 2011-12-09 12:50:00

# %%
import datetime as dt

today_date=dt.datetime(2011,12,11)

today_date
# Out:
# datetime.datetime(2011, 12, 11, 0, 0)

# %% [markdown]
# # **CRECION DE TABLA PARA APLICAR LOS MODELOS CLTV PREDICTION Y RFM**

# %%
#Armamos la tabla de clientes con:
# - El periodo entre la ultima y la primera compra
# - El periodo entre hoy y la ultima compra
# - El periodo entre hoy y la primera compra
# - Cantidad total de compras
# - Monto total de compra

cltv_c=df.groupby('Customer ID').agg({'InvoiceDate':[lambda x:(today_date-x.max()).days,lambda x:(today_date-x.min()).days],
                                      'Invoice': lambda x : x.nunique(),
                                      'TotalPrice': lambda x : x.sum()
                                      })


cltv_c.head()
# Out:
#             InvoiceDate             Invoice TotalPrice
#              <lambda_0> <lambda_1> <lambda>   <lambda>
# Customer ID
# 12346.0             326        726       12   77556.46
# 12347.0               3        405        8    5633.32
# 12348.0              76        439        5    2019.40
# 12349.0              19        590        4    4428.69
# 12350.0             311        311        1     334.40

# %%
#Eliminamos la primera fila con de nombres de colummnas

cltv_c.columns=cltv_c.columns.droplevel(0)

cltv_c.head()
# Out:
#              <lambda_0>  <lambda_1>  <lambda>  <lambda>
# Customer ID
# 12346.0             326         726        12  77556.46
# 12347.0               3         405         8   5633.32
# 12348.0              76         439         5   2019.40
# 12349.0              19         590         4   4428.69
# 12350.0             311         311         1    334.40

# %%
#Asignamos los nombres a las columnas
cltv_c.columns=["recency","T","frequency","monetary"]

cltv_c
# Out:
#              recency    T  frequency  monetary
# Customer ID
# 12346.0          326  726         12  77556.46
# 12347.0            3  405          8   5633.32
# 12348.0           76  439          5   2019.40
# 12349.0           19  590          4   4428.69
# 12350.0          311  311          1    334.40
# ...              ...  ...        ...       ...
# 18283.0            4  659         22   2736.65
# 18284.0          432  432          1    461.68
# 18285.0          661  661          1    427.00
# 18286.0          477  724          2   1296.43
# 18287.0           43  572          7   4182.99
#
# [5881 rows x 4 columns]

# %%
#Pasamos los dias a semanas y sacamos los que tiene frecuencia 0 y modificamos la columna monetary teniendo en cuenta los montos por compra

cltv_c["recency"]=cltv_c["recency"]/7
cltv_c["T"]=cltv_c["T"]/7
cltv_c=cltv_c[cltv_c["frequency"]>1]
cltv_c["monetary"]=cltv_c["monetary"]/cltv_c["frequency"]

cltv_c.columns=["recency_w","T_w","frequency","monetary_avg"]

cltv_c
# Out:
#              recency_w         T_w  frequency  monetary_avg
# Customer ID
# 12346.0      46.571429  103.714286         12   6463.038333
# 12347.0       0.428571   57.857143          8    704.165000
# 12348.0      10.857143   62.714286          5    403.880000
# 12349.0       2.714286   84.285714          4   1107.172500
# 12352.0       5.285714   56.142857         10    284.984000
# ...                ...         ...        ...           ...
# 18281.0      25.857143   82.571429          2    100.570000
# 18282.0       1.142857   18.142857          2     89.025000
# 18283.0       0.571429   94.142857         22    124.393182
# 18286.0      68.142857  103.428571          2    648.215000
# 18287.0       6.142857   81.714286          7    597.570000
#
# [4255 rows x 4 columns]

# %% [markdown]
# # **MODELO CLTV PREDICTION (Valor Futuro del Cliente)**

# %%
# !pip install lifetimes

# %% [markdown]
# **SUBMODEL BETAGEOFITTER**

# %%
#Aplicamos el Modelo BetaGeoFitter que permite modelar la probabilidad de que el cliente compre en el futuro

from lifetimes import BetaGeoFitter

bgf=BetaGeoFitter(penalizer_coef=0.001) #Aplicamos un coef de penalizacion de 0.001 para evitar valores extremos y mejorar la estabilidad del ajuste.

bgf.fit(cltv_c["frequency"],cltv_c["recency_w"],cltv_c["T_w"])
# Out:
# <lifetimes.BetaGeoFitter: fitted with 4255 subjects, a: 1.35, alpha: 0.04, b: 7.03, r: 0.27>

# %%
#Top 10 de clientes que esperamos que mas compren una semana desde su ultima compra
bgf.conditional_expected_number_of_purchases_up_to_time(1,cltv_c["frequency"],cltv_c["recency_w"],cltv_c["T_w"]).sort_values(ascending=False).head(10)
# Out:
# Customer ID
# 16000.0    4.120673
# 15060.0    2.031600
# 18139.0    1.758191
# 16479.0    1.072929
# 12452.0    0.727384
# 17509.0    0.711213
# 17100.0    0.656948
# 14785.0    0.647144
# 17523.0    0.625420
# 13596.0    0.561849
# dtype: float64

# %%
#Agregamos a la table la Prediccion de compras semanal y semestral
cltv_c["expected_purc_1_week"]=bgf.conditional_expected_number_of_purchases_up_to_time(1,cltv_c["frequency"],cltv_c["recency_w"],cltv_c["T_w"]) #Predice 7 dias desde la ultima compra
cltv_c["expected_purc_6_month"]=bgf.predict(4*6,cltv_c["frequency"],cltv_c["recency_w"],cltv_c["T_w"]) #Predice en lo proximos 6 meses(Pero no desde la ultima compra)

#Le cambio el formato
#cltv_c["expected_purc_1_week"] = cltv_c["expected_purc_1_week"].apply(lambda x: round(x, 6))
#cltv_c["expected_purc_6_month"] = cltv_c["expected_purc_6_month"].apply(lambda x: round(x, 7))

cltv_c.head()
# Out:
#              recency_w         T_w  frequency  monetary_avg  \
# Customer ID
# 12346.0      46.571429  103.714286         12   6463.038333
# 12347.0       0.428571   57.857143          8    704.165000
# 12348.0      10.857143   62.714286          5    403.880000
# 12349.0       2.714286   84.285714          4   1107.172500
# 12352.0       5.285714   56.142857         10    284.984000
#
#              expected_purc_1_week  expected_purc_6_month
# Customer ID
# 12346.0              8.554909e-05           1.874591e-03
# 12347.0              6.840412e-18           1.432259e-16
# 12348.0              6.709671e-05           1.447951e-03
# 12349.0              1.687372e-07           3.762137e-06
# 12352.0              6.640108e-11           1.370323e-09

# %%
#Ventas esperadas en los proximos 6 meses
cltv_c["expected_purc_6_month"].sum()
# Out:
# 1202.151680512191

# %%
from lifetimes.plotting import plot_period_transactions
#Graficamos la comparacion entre los valores que muestra el modelo y los valores actuales
plot_period_transactions(bgf)
plt.title('Gráfico de Frecuencia de Compras por Período')
plt.xlabel('Número de compras en el período')
plt.ylabel('Cantidad de clientes')
plt.show()

# %% [markdown]
# **SUBMODEL GAMMA-GAMMA**

# %%
from lifetimes import GammaGammaFitter

#Aplicamos el Modelo Gamma-Gamma que permite estimar el valor monetario promedio de las compras de cada cliente

ggf=GammaGammaFitter(penalizer_coef=0.01)
ggf.fit(cltv_c["frequency"],cltv_c["monetary_avg"])
# Out:
# <lifetimes.GammaGammaFitter: fitted with 4255 subjects, p: 3.79, q: 0.34, v: 3.73>

# %%
#Top 10 de clientes que esperamos que mas ganacias generen
ggf.conditional_expected_average_profit(cltv_c["frequency"],cltv_c["monetary_avg"]).sort_values(ascending=False).head(10)
# Out:
# Customer ID
# 16446.0    92282.275501
# 15749.0    15761.982572
# 15098.0    14127.746000
# 15760.0     7624.672201
# 13902.0     7066.179570
# 12346.0     6558.634450
# 12357.0     6473.312863
# 12590.0     5405.159364
# 14091.0     5222.113422
# 12415.0     5191.686150
# dtype: float64

# %%
cltv_c["expected_average_profit"]=ggf.conditional_expected_average_profit(cltv_c["frequency"],cltv_c["monetary_avg"])
cltv_c.head()
# Out:
#              recency_w         T_w  frequency  monetary_avg  \
# Customer ID
# 12346.0      46.571429  103.714286         12   6463.038333
# 12347.0       0.428571   57.857143          8    704.165000
# 12348.0      10.857143   62.714286          5    403.880000
# 12349.0       2.714286   84.285714          4   1107.172500
# 12352.0       5.285714   56.142857         10    284.984000
#
#              expected_purc_1_week  expected_purc_6_month  \
# Customer ID
# 12346.0              8.554909e-05           1.874591e-03
# 12347.0              6.840412e-18           1.432259e-16
# 12348.0              6.709671e-05           1.447951e-03
# 12349.0              1.687372e-07           3.762137e-06
# 12352.0              6.640108e-11           1.370323e-09
#
#              expected_average_profit
# Customer ID
# 12346.0                  6558.634450
# 12347.0                   720.329288
# 12348.0                   419.244759
# 12349.0                  1158.603030
# ...

# %% [markdown]
# **CALCULAMOS EL CLTV VALUE**

# %%
cltv_c["cltv_6"]=ggf.customer_lifetime_value(bgf,
                                             cltv_c["frequency"],cltv_c["recency_w"],cltv_c["T_w"],cltv_c["monetary_avg"],
                                             time=6,freq="W",discount_rate=0.01)
cltv_c.head()
# Out:
#              recency_w         T_w  frequency  monetary_avg  \
# Customer ID
# 12346.0      46.571429  103.714286         12   6463.038333
# 12347.0       0.428571   57.857143          8    704.165000
# 12348.0      10.857143   62.714286          5    403.880000
# 12349.0       2.714286   84.285714          4   1107.172500
# 12352.0       5.285714   56.142857         10    284.984000
#
#              expected_purc_1_week  expected_purc_6_month  \
# Customer ID
# 12346.0              8.554909e-05           1.874591e-03
# 12347.0              6.840412e-18           1.432259e-16
# 12348.0              6.709671e-05           1.447951e-03
# 12349.0              1.687372e-07           3.762137e-06
# 12352.0              6.640108e-11           1.370323e-09
#
#              expected_average_profit        cltv_6
# Customer ID
# 12346.0                  6558.634450  1.281407e+01
# 12347.0                   720.329288  1.072093e-13
# 12348.0                   419.244759  6.320655e-01
# ...

# %%
#top 10 CLTV
cltv_c.sort_values("cltv_6",ascending=False).head(10)
# Out:
#              recency_w         T_w  frequency  monetary_avg  \
# Customer ID
# 16000.0       0.428571    0.428571          3   4131.233333
# 15098.0      26.142857   26.142857          3  13305.500000
# 18139.0       2.571429    2.714286          6   1406.390000
# 12536.0       6.285714    8.571429          3   4200.610000
# 15749.0      33.714286   47.571429          3  14844.766667
# 17509.0       8.285714    9.142857          8    764.392500
# 12590.0      30.285714   30.285714          2   4932.130000
# 13902.0      90.428571  103.571429          5   6819.052000
# 15760.0      90.142857   90.142857          2   6958.170000
# 17100.0       2.714286    2.714286          2    485.870000
#
#              expected_purc_1_week  expected_purc_6_month  \
# Customer ID
# 16000.0                  4.120673              15.816282
# 15098.0                  0.107590               2.138922
# 18139.0                  1.758191              14.097125
# ...

# %% [markdown]
# **SEGMENTOS CON MODELO CLTV**

# %%
cltv_c["segment_CLTV"]=pd.qcut(cltv_c["cltv_6"],4,labels=["D","C","B","A"])
cltv_c.head()
# Out:
#              recency_w         T_w  frequency  monetary_avg  \
# Customer ID
# 12346.0      46.571429  103.714286         12   6463.038333
# 12347.0       0.428571   57.857143          8    704.165000
# 12348.0      10.857143   62.714286          5    403.880000
# 12349.0       2.714286   84.285714          4   1107.172500
# 12352.0       5.285714   56.142857         10    284.984000
#
#              expected_purc_1_week  expected_purc_6_month  \
# Customer ID
# 12346.0              8.554909e-05           1.874591e-03
# 12347.0              6.840412e-18           1.432259e-16
# 12348.0              6.709671e-05           1.447951e-03
# 12349.0              1.687372e-07           3.762137e-06
# 12352.0              6.640108e-11           1.370323e-09
#
#              expected_average_profit        cltv_6 segment_CLTV
# Customer ID
# 12346.0                  6558.634450  1.281407e+01            B
# 12347.0                   720.329288  1.072093e-13            D
# ...

# %%
#Mostramos el promedio, cantidad, y suma de cada segmento

pd.set_option("display.max_columns",None) #Es para que muestre todas las columnas
cltv_c.groupby("segment_CLTV").agg(["mean", "count", "sum"])
# Out:
#               recency_w                            T_w                      \
#                    mean count           sum       mean count           sum
# segment_CLTV
# D              3.196697  1064   3401.285714  91.059748  1064  96887.571429
# C              8.194280  1064   8718.714286  74.953410  1064  79750.428571
# B             27.500202  1063  29232.714286  71.199301  1063  75684.857143
# A             42.933673  1064  45681.428571  60.417159  1064  64283.857143
#
#               frequency              monetary_avg                       \
#                    mean count    sum         mean count            sum
# segment_CLTV
# D             20.500940  1064  21813   444.550837  1064  473002.090770
# C              6.178571  1064   6574   354.975912  1064  377694.370191
# B              3.662277  1063   3893   384.427126  1063  408646.035017
# A              2.884398  1064   3069   446.430827  1064  475002.400231
#
# ...

# %% [markdown]
# # **MODELO RFM**

# %%
#Armamos una copia de la tabla CLTV

rfm =cltv_c.copy()
rfm
# Out:
#              recency_w         T_w  frequency  monetary_avg  \
# Customer ID
# 12346.0      46.571429  103.714286         12   6463.038333
# 12347.0       0.428571   57.857143          8    704.165000
# 12348.0      10.857143   62.714286          5    403.880000
# 12349.0       2.714286   84.285714          4   1107.172500
# 12352.0       5.285714   56.142857         10    284.984000
# ...                ...         ...        ...           ...
# 18281.0      25.857143   82.571429          2    100.570000
# 18282.0       1.142857   18.142857          2     89.025000
# 18283.0       0.571429   94.142857         22    124.393182
# 18286.0      68.142857  103.428571          2    648.215000
# 18287.0       6.142857   81.714286          7    597.570000
#
#              expected_purc_1_week  expected_purc_6_month  \
# Customer ID
# 12346.0              8.554909e-05           1.874591e-03
# 12347.0              6.840412e-18           1.432259e-16
# ...

# %% [markdown]
# **RFM SCORES**

# %%
#Score Recenty
rfm["recency_score"] = pd.qcut(rfm["recency_w"], 5, labels=[5, 4, 3, 2, 1])

rfm.head(10)
# Out:
#              recency_w         T_w  frequency  monetary_avg  \
# Customer ID
# 12346.0      46.571429  103.714286         12   6463.038333
# 12347.0       0.428571   57.857143          8    704.165000
# 12348.0      10.857143   62.714286          5    403.880000
# 12349.0       2.714286   84.285714          4   1107.172500
# 12352.0       5.285714   56.142857         10    284.984000
# 12353.0      29.285714   58.428571          2    203.380000
# 12355.0      30.714286   81.142857          2    473.805000
# 12356.0       3.285714   60.714286          6   1062.280000
# 12357.0       4.857143   55.571429          3   6095.886667
# 12358.0       0.285714  104.571429          5    777.414000
#
#              expected_purc_1_week  expected_purc_6_month  \
# Customer ID
# 12346.0              8.554909e-05           1.874591e-03
# 12347.0              6.840412e-18           1.432259e-16
# 12348.0              6.709671e-05           1.447951e-03
# ...

# %%
#Score frequency
rfm["frequency_score"] = pd.qcut(rfm['frequency'].rank(method="first"), 5, labels=[1, 2, 3, 4, 5])

rfm.head(10)
# Out:
#              recency_w         T_w  frequency  monetary_avg  \
# Customer ID
# 12346.0      46.571429  103.714286         12   6463.038333
# 12347.0       0.428571   57.857143          8    704.165000
# 12348.0      10.857143   62.714286          5    403.880000
# 12349.0       2.714286   84.285714          4   1107.172500
# 12352.0       5.285714   56.142857         10    284.984000
# 12353.0      29.285714   58.428571          2    203.380000
# 12355.0      30.714286   81.142857          2    473.805000
# 12356.0       3.285714   60.714286          6   1062.280000
# 12357.0       4.857143   55.571429          3   6095.886667
# 12358.0       0.285714  104.571429          5    777.414000
#
#              expected_purc_1_week  expected_purc_6_month  \
# Customer ID
# 12346.0              8.554909e-05           1.874591e-03
# 12347.0              6.840412e-18           1.432259e-16
# 12348.0              6.709671e-05           1.447951e-03
# ...

# %%
#Score Monetary
rfm["monetary_score"] = pd.qcut(rfm['monetary_avg'], 5, labels=[1, 2, 3, 4, 5])

rfm
# Out:
#              recency_w         T_w  frequency  monetary_avg  \
# Customer ID
# 12346.0      46.571429  103.714286         12   6463.038333
# 12347.0       0.428571   57.857143          8    704.165000
# 12348.0      10.857143   62.714286          5    403.880000
# 12349.0       2.714286   84.285714          4   1107.172500
# 12352.0       5.285714   56.142857         10    284.984000
# ...                ...         ...        ...           ...
# 18281.0      25.857143   82.571429          2    100.570000
# 18282.0       1.142857   18.142857          2     89.025000
# 18283.0       0.571429   94.142857         22    124.393182
# 18286.0      68.142857  103.428571          2    648.215000
# 18287.0       6.142857   81.714286          7    597.570000
#
#              expected_purc_1_week  expected_purc_6_month  \
# Customer ID
# 12346.0              8.554909e-05           1.874591e-03
# 12347.0              6.840412e-18           1.432259e-16
# ...

# %%
#Score RF
rfm["RF_SCORE"] = (rfm["recency_score"].astype(str) + rfm["frequency_score"].astype(str))

rfm
# Out:
#              recency_w         T_w  frequency  monetary_avg  \
# Customer ID
# 12346.0      46.571429  103.714286         12   6463.038333
# 12347.0       0.428571   57.857143          8    704.165000
# 12348.0      10.857143   62.714286          5    403.880000
# 12349.0       2.714286   84.285714          4   1107.172500
# 12352.0       5.285714   56.142857         10    284.984000
# ...                ...         ...        ...           ...
# 18281.0      25.857143   82.571429          2    100.570000
# 18282.0       1.142857   18.142857          2     89.025000
# 18283.0       0.571429   94.142857         22    124.393182
# 18286.0      68.142857  103.428571          2    648.215000
# 18287.0       6.142857   81.714286          7    597.570000
#
#              expected_purc_1_week  expected_purc_6_month  \
# Customer ID
# 12346.0              8.554909e-05           1.874591e-03
# 12347.0              6.840412e-18           1.432259e-16
# ...

# %%
#Clientes Campeones

rfm[rfm["RF_SCORE"] == "55"].head(10)
# Out:
#              recency_w         T_w  frequency  monetary_avg  \
# Customer ID
# 12417.0       0.571429  104.857143         20    340.845500
# 12437.0       0.285714  105.428571         39    325.215385
# 12471.0       0.428571  104.714286         79    505.870759
# 12490.0       0.857143  105.571429         21    467.792381
# 12524.0       1.428571   95.714286         17    654.477059
# 12553.0       1.285714   60.571429         12    384.062500
# 12569.0       0.428571   36.142857         32    128.896563
# 12583.0       0.428571  104.857143         27    535.090370
# 12621.0       0.285714   95.571429         35    707.880286
# 12662.0       0.142857   88.285714         20    349.401000
#
#              expected_purc_1_week  expected_purc_6_month  \
# Customer ID
# 12417.0              1.630639e-45           3.531034e-44
# 12437.0              1.858293e-98           3.975098e-97
# 12471.0             1.250672e-185          2.650461e-184
# ...

# %% [markdown]
# **CREACION DE SEGMENTOS RFM**

# %%
seg_map = {
    r'[1-2][1-2]': 'hibernating',
    r'[1-2][3-4]': 'at_Risk',
    r'[1-2]5': 'cant_loose',
    r'3[1-2]': 'about_to_sleep',
    r'33': 'need_attention',
    r'[3-4][4-5]': 'loyal_customers',
    r'41': 'promising',
    r'51': 'new_customers',
    r'[4-5][2-3]': 'potential_loyalists',
    r'5[4-5]': 'champions'
}

rfm['segment_RFM'] = rfm['RF_SCORE'].replace(seg_map, regex=True)

rfm
# Out:
#              recency_w         T_w  frequency  monetary_avg  \
# Customer ID
# 12346.0      46.571429  103.714286         12   6463.038333
# 12347.0       0.428571   57.857143          8    704.165000
# 12348.0      10.857143   62.714286          5    403.880000
# 12349.0       2.714286   84.285714          4   1107.172500
# 12352.0       5.285714   56.142857         10    284.984000
# ...                ...         ...        ...           ...
# 18281.0      25.857143   82.571429          2    100.570000
# 18282.0       1.142857   18.142857          2     89.025000
# 18283.0       0.571429   94.142857         22    124.393182
# 18286.0      68.142857  103.428571          2    648.215000
# 18287.0       6.142857   81.714286          7    597.570000
#
#              expected_purc_1_week  expected_purc_6_month  \
# Customer ID
# 12346.0              8.554909e-05           1.874591e-03
# 12347.0              6.840412e-18           1.432259e-16
# ...

# %%
#Mostramos el promedio, cantidad, y suma de cada segmento

pd.set_option("display.max_columns",None) #Es para que muestre todas las columnas
rfm.groupby("segment_RFM").agg(["mean", "count", "sum"])
# Out:
#                      recency_w                            T_w        \
#                           mean count           sum       mean count
# segment_RFM
# about_to_sleep        8.953979   298   2668.285714  51.808245   298
# at_Risk              38.775176   610  23652.857143  87.925059   610
# cant_loose           31.164502    99   3085.285714  97.034632    99
# champions             0.967726   571    552.571429  84.125844   571
# hibernating          49.530281   986  48836.857143  75.578093   986
# loyal_customers       5.816301   794   4618.142857  88.534545   794
# need_attention        9.033449   205   1851.857143  74.034146   205
# new_customers         1.103175    72     79.428571  21.297619    72
# potential_loyalists   2.508062   505   1266.571429  48.647242   505
# promising             3.672050   115    422.285714  33.022360   115
#
#                                    frequency              monetary_avg        \
# ...
